# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('data/abalone.csv')

# %%
df.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.info()
#sns.heatmap(df.isnull())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               4177 non-null object
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole weight      4177 non-null float64
# Shucked weight    4177 non-null float64
# Viscera weight    4177 non-null float64
# Shell weight      4177 non-null float64
# Rings             4177 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
print(df.skew(),df.kurtosis())
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64 Length             0.064621
# Diameter          -0.045476
# Height            76.025509
# Whole weight      -0.023644
# Shucked weight     0.595124
# Viscera weight     0.084012
# Shell weight       0.531926
# Rings              2.330687
# dtype: float64

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
df1=df.drop('Sex',axis=1)
fig, axes = plt.subplots(nrows=2,ncols=4, figsize=(30,15))
for i,column in enumerate(df1.columns):
    sns.distplot(df1[column],ax=axes[i%2,i//2])

# %%
fig, ax = plt.subplots(ncols=2,figsize=[30,15])
df.drop('Rings',axis=1).boxplot(ax=ax[0],figsize=[15,15])
pd.DataFrame(df['Rings']).boxplot(ax=ax[1],figsize=[10,15])

# %% [markdown]
# ## model training

# %%
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from yellowbrick.classifier import ClassificationReport, ClassPredictionError, ConfusionMatrix
from yellowbrick.classifier import ROCAUC,PrecisionRecallCurve

from sklearn import metrics
from sklearn.metrics import classification_report,roc_curve,auc,roc_auc_score
from sklearn.metrics import cohen_kappa_score,hamming_loss,log_loss,zero_one_loss,matthews_corrcoef

# %%
x=df.drop('Sex',axis=1)
y=label_binarize(df['Sex'],classes=['M','F','I'])
n_classes=y.shape[1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((3341, 8), (836, 8), (3341, 3), (836, 3))

# %%
clf=OneVsRestClassifier(LogisticRegression(solver='lbfgs',multi_class='multinomial'))

# %%
clf.fit(x_train,y_train)
y_score=clf.decision_function(x_test)

# %%
fpr=dict()
tpr=dict()
roc_auc=dict()
for i in range(n_classes):
    fpr[i],tpr[i],_=roc_curve(y_test[:,i],y_score[:,i])
    roc_auc[i]=auc(fpr[i],tpr[i])

# %%
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i],tpr[i],lw=2,label='ROC Curve Area for class {0}: {1:0.2f}'''.format(i,roc_auc[i]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
y_pred=clf.predict(x_test)

# %%
for i in range(n_classes):
    print('Class {0} Scores'''.format(i))
    print(classification_report(y_test[:,i],y_pred[:,i]))
# Out:
# Class 0 Scores
#               precision    recall  f1-score   support
#
#            0       0.66      0.90      0.76       529
#            1       0.51      0.19      0.27       307
#
#     accuracy                           0.64       836
#    macro avg       0.58      0.54      0.52       836
# weighted avg       0.60      0.64      0.58       836
#
# Class 1 Scores
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.82       574
#            1       0.60      0.20      0.30       262
#
#     accuracy                           0.71       836
#    macro avg       0.66      0.57      0.56       836
# weighted avg       0.68      0.71      0.65       836
#
# Class 2 Scores
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       569
#            1       0.74      0.72      0.73       267
#
#     accuracy                           0.83       836
# ...

# %%
for i in range(n_classes):
    print('Confusion Matrix Class {0}'''.format(i))
    print(metrics.confusion_matrix(y_test[:,i],y_pred[:,i]))
# Out:
# Confusion Matrix Class 0
# [[475  54]
#  [250  57]]
# Confusion Matrix Class 1
# [[539  35]
#  [209  53]]
# Confusion Matrix Class 2
# [[502  67]
#  [ 75 192]]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cd,annot=True,fmt=".3f", linewidths=.5, square = True,cmap = 'Blues_r')
plt.ylabel('Actual')
plt.xlabel('Predicted')

# %% [markdown]
# ## Model saving

# %%
from sklearn.externals import joblib

# %%
PATH_MODEL = './model/clf_saved.sav'
joblib.dump(clf,PATH_MODEL)

# %%
# model loading
clf_loaded = joblib.load(PATH_MODEL)

# %%
clf_loaded.predict(x_test)
